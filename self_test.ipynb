# %%
from common.AutoAdb import AutoAdb
import time

from common import PathUtils
from common.Location import Location
from bin.StartFish import StartFish
# 选择关卡stage
from common.Timer import Timer

# %%
AutoAdb(test_device=True)
adb = AutoAdb()
# Out:
# ADB PATH >>>> d:/learn/lhcx/adb/adb.exe
# 检测设备连接状态 >>> 127.0.0.1:7555 ...
#
# 设备列表：
# 127.0.0.1:7555	device
#
# 设备已连接
#
# 屏幕分辨率: Physical size: 1280x720
# 像素密度: Physical density: 240
# 系统类型: x86_64
# 系统版本: 6.0.1

# %%
adb.click('temp_images/start2.png')
# Out:
# True

# %%
work_dir = PathUtils.get_work_dir()
fishing_image_path = '/temp_images/screen_fish.jpg'

# %%
ending_loc = Location(adb, None, 600, 600)
for i in range(1):
    adb.click('temp_images/fish.png')
    time.sleep(2)
    adb.click('temp_images/start.png')
    now = time.time()
    while time.time() - now <60*1:
        StartFish.window_capture(work_dir+fishing_image_path)
        x, y = StartFish.get_position(work_dir+fishing_image_path)
        ring = StartFish.Stage(x, y)
        if ring:
            adb.swipe(600, 600, 800, 600, 700)
    ending_loc.click()
    ending_loc.click()
# Out:
# 1342 799
# 向左运动
# 1518 806
# 向左运动
# 1632 825
# 向左运动
# 1731 832
# 向左运动
# 1767 842
# 向左运动
# 1767 842
# 向左运动
# 1767 842
# 向右运动
# 1424 982
# 向左运动
# 1360 1028
# 向左运动
# 1312 1051
# 向左运动
# 1286 1064
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1280 1068
# 向左运动
# 1294 1020
# 向左运动
# 1315 968
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1321 953
# 向右运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1321 953
# 向左运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1321 953
# 向左运动
# 1321 953
# 向右运动
# 1320 953
# 向右运动
# 1318 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向右运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1317 954
# 向左运动
# 1315 955
# 向左运动
# 1315 955
# 向左运动
# 1315 955
# 向左运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1315 955
# 向左运动
# 1315 955
# 向左运动
# 1315 955
# 向左运动
# 1315 955
# 向右运动
# 1315 955
# 向右运动
# 1261 973
# 向左运动
# 1261 973
# 向左运动
# 1261 973
# 向左运动
# 1261 973
# 向右运动
# 1261 973
# 向左运动
# 1261 973
# 向左运动
# 1261 973
# 向右运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向右运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向左运动
# 1261 974
# 向右运动
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7204\1018346970.py in <module>
#       8         StartFish.window_capture(work_dir+fishing_image_path)
#       9         x, y = StartFish.get_position(work_dir+fishing_image_path)
# ---> 10         ring = StartFish.Stage(x, y)
#      11         if ring:
#      12             adb.swipe(600, 600, 800, 600, 700)
#
# d:\learn\lhcx\bin\StartFish.py in Stage(region, fish, during_time)
#      64
#      65         currentMouseX, currentMouseY = pyautogui.position() # 鼠标当前位置
# ---> 66         pyautogui.moveTo(1000, 1000, duration=0.001)
#      67         print(currentMouseX, currentMouseY)
#      68         # 长点屏幕
#
# d:\anaconda\envs\tf27\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     595     @functools.wraps(wrappedFunction)
#     596     def wrapper(*args, **kwargs):
# --> 597         failSafeCheck()
#     598         returnVal = wrappedFunction(*args, **kwargs)
#     599         _handlePause(kwargs.get("_pause", True))
#
# d:\anaconda\envs\tf27\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1721     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
#    1722         raise FailSafeException(
# -> 1723             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1724         )
#    1725
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.
